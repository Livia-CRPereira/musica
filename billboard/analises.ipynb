# %%
import math
import numpy as np
import matplotlib.pyplot as pyplot

# !pip install babypandas
import babypandas as bpd
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       3 import matplotlib.pyplot as pyplot
#       5 # !pip install babypandas
# ----> 6 import babypandas as bpd
#       7 import pandas as pd
#
# File c:\Users\livia\AppData\Local\Programs\Python\Python39\lib\site-packages\babypandas\__init__.py:1
# ----> 1 from babypandas.bpd import DataFrame, Series, DataFrameGroupBy, read_csv
#
# File c:\Users\livia\AppData\Local\Programs\Python\Python39\lib\site-packages\babypandas\bpd.py:4
#       1 from collections.abc import Iterable
#       3 import numpy as np
# ----> 4 import pandas as pd
#       6 from pandas.core import common as com
#       7 from pandas.core import indexing
#
# File c:\Users\livia\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py:22
#      19 del hard_dependencies, dependency, missing_dependencies
# ...

# %%
songsArtists = bpd.read_csv('songs_and_artists_updated.csv')
songsArtists
# Out:
#       Year  Position                        Song  \
# 0     1960         1   Theme From A Summer Place
# 1     1960         2                Banho De Lua
# 2     1960         3          A Noite Do Meu Bem
# 3     1960         4                   Esmeralda
# 4     1960         5            Mulher De Trinta
# ...    ...       ...                         ...
# 6395  2023        96                Haja colirio
# 6396  2023        97                         Ela
# 6397  2023        98  Perfeito pra ficar sozinho
# 6398  2023        99            Daqui pra sempre
# 6399  2023       100               Te amo demais
#
#                                     Artist         Country             Genre
# 0                              Percy Faith          Canada   death by cancer
# 1                           Celly Campello          Brazil     rock and roll
# 2                            Dolores Duran  Rio de Janeiro             samba
# ...

# %%
songsArtists[songsArtists.get('Artist') == 'Adele']
# Out:
#       Year  Position                  Song Artist         Country Genre
# 5110  2011        11   Rolling in the deep  Adele  United Kingdom   pop
# 5124  2011        25      Someone Like You  Adele  United Kingdom   pop
# 5202  2012         3  Set Fire To The Rain  Adele  United Kingdom   pop
# 5204  2012         5      Someone Like You  Adele  United Kingdom   pop
